# %% [markdown]
# ## Check any incorrect ssdm id/password from config.json

# %%
from pathlib import Path
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.alert import Alert
import json

current_dir = Path.cwd()
config_dir = current_dir / "config.json"

# set options for chrome
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-gpu")

# Read data from the JSON file
with open(config_dir, 'r') as jsonfile:
    config = json.load(jsonfile)

school = config['JOHOR']

driver = webdriver.Chrome(options=chrome_options)
wait = WebDriverWait(driver, 10)
driver.set_script_timeout(10)

for row in school:
    driver.get("https://ssdm.moe.gov.my/")
    print( "CHECKING FOR " + row['NAME'])
    
    login_box, pass_box = wait.until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR , "input[name='id'], input[name='password']")))
    login_box.send_keys(row['ID'])
    pass_box.send_keys(row['PASS'])
    wait.until(EC.element_to_be_clickable((By.XPATH, "//input[@class='button']"))).click()
    
    try:
        alert = Alert(driver)
        alert.accept()
        print("is not okay")
    except Exception as e:
        print("is okay")
        driver.find_element(By.XPATH, "//a[@href='logout1.cfm']").click()
        pass  
    
        
time.sleep(1)
driver.close()
# Out:
# CHECKING FOR KV (ERT) AZIZAH
# is not okay
# CHECKING FOR KV PERDAGANGAN
# is okay
# CHECKING FOR KV TANJUNG PUTERI
# is okay
# CHECKING FOR MAKTAB SULTAN ABU BAKAR
# is okay
# CHECKING FOR SEKOLAH TUN FATIMAH
# is okay
# CHECKING FOR SJK (CINA) CHEAH FAH
# is okay
# CHECKING FOR SJK (CINA) FOON YEW 1
# is okay
# CHECKING FOR SJK (CINA) FOON YEW 2
# is okay
# CHECKING FOR SJK (CINA) FOON YEW 3
# is okay
# CHECKING FOR SJK (CINA) FOON YEW 4
# is okay
# CHECKING FOR SJK (CINA) KEMPAS BARU
# is okay
# CHECKING FOR SJK (CINA) KUO KUANG 2
# is okay
# CHECKING FOR SJK (CINA) KUO KUANG
# is okay
# CHECKING FOR SJK (CINA) MING CHIH
# is okay
# CHECKING FOR SJK (CINA) MING TERK
# is okay
# CHECKING FOR SJK (CINA) PAI TZE
# is okay
# CHECKING FOR SJK (CINA) PEI HWA
# is okay
# CHECKING FOR SJK (CINA) PING MING
# is okay
# CHECKING FOR SJK (CINA) PU SZE
# is okay
# CHECKING FOR SJK (CINA) ST JOSEPH
# is okay
# CHECKING FOR SJK (CINA) TAMPOI
# is okay
# CHECKING FOR SJK (CINA) THAI HONG
# is okay
# CHECKING FOR SJK (CINA) THORBURN
# is okay
# CHECKING FOR SJK (TAMIL) GELANG PATAH
# is okay
# CHECKING FOR SJK (TAMIL) JALAN YAHYA AWAL
# is okay
# CHECKING FOR SJK (TAMIL) LADANG BUKIT SERAMPANG
# is okay
# CHECKING FOR SJK (TAMIL) LADANG RINI
# is okay
# CHECKING FOR SJK (TAMIL) TAMAN TUN AMINAH
# is okay
# CHECKING FOR SK (P) BANDAR TINGGI
# is okay
# CHECKING FOR SK (P) JLN. YAHYA AWAL
# is okay
# CHECKING FOR SK (P) SULTAN IBRAHIM
# is okay
# CHECKING FOR SK ANGKATAN TENTERA
# is okay
# CHECKING FOR SK AYER MOLEK
# is okay
# CHECKING FOR SK BANDAR UDA 2
# is okay
# CHECKING FOR SK BUKIT MUTIARA
# is okay
# CHECKING FOR SK GELANG PATAH
# is okay
# CHECKING FOR SK INFANT JESUS CONVENT
# is okay
# CHECKING FOR SK KAMPUNG PULAI
# is okay
# CHECKING FOR SK KEMPAS
# is okay
# CHECKING FOR SK KG PASIR
# is okay
# CHECKING FOR SK KG. MAJU JAYA
# is okay
# CHECKING FOR SK KOMPLEKS SULTAN ABU BAKAR
# is okay
# CHECKING FOR SK KOMPLEKS UDA
# is okay
# CHECKING FOR SK LADANG PENDAS
# is okay
# CHECKING FOR SK LARKIN 1
# is okay
# CHECKING FOR SK LARKIN 2
# is okay
# CHECKING FOR SK MAJIDI BARU
# is okay
# CHECKING FOR SK MEDINI
# is okay
# CHECKING FOR SK MOHD KHIR JOHARI
# is okay
# CHECKING FOR SK MORNI POK
# is okay
# CHECKING FOR SK NGEE HENG
# is okay
# CHECKING FOR SK NONG CHIK
# is okay
# CHECKING FOR SK NUSANTARA
# is okay
# CHECKING FOR SK PENDAS LAUT
# is okay
# CHECKING FOR SK PENDIDIKAN KHAS JOHOR BAHRU
# is okay
# CHECKING FOR SK PENDIDIKAN KHAS PRINCESS ELIZABETH
# is okay
# CHECKING FOR SK PENGKALAN RINTING
# is okay
# CHECKING FOR SK PERUMAHAN TAMPOI 2
# is okay
# CHECKING FOR SK SEKUDAI BT 10
# is okay
# CHECKING FOR SK SERI KENANGA
# is okay
# CHECKING FOR SK SERI MELATI
# is okay
# CHECKING FOR SK SERI PERLING 2
# is okay
# CHECKING FOR SK SIKIJANG
# is okay
# CHECKING FOR SK SRI AMAR
# is okay
# CHECKING FOR SK SRI SKUDAI
# is okay
# CHECKING FOR SK SRI TEBRAU
# is okay
# CHECKING FOR SK ST. JOSEPH
# is okay
# CHECKING FOR SK SUNGAI DANGA
# is okay
# CHECKING FOR SK SUNGAI MELAYU
# is okay
# CHECKING FOR SK TAMAN ANGGERIK
# is okay
# CHECKING FOR SK TAMAN BUKIT INDAH
# is okay
# CHECKING FOR SK TAMAN BUKIT KEMPAS
# is okay
# CHECKING FOR SK TAMAN BUKIT MEWAH
# is okay
# CHECKING FOR SK TAMAN CEMPAKA
# is okay
# CHECKING FOR SK TAMAN DAMAI JAYA
# is okay
# CHECKING FOR SK TAMAN DAMANSARA ALIFF
# is okay
# CHECKING FOR SK TAMAN DESA SKUDAI
# is okay
# CHECKING FOR SK TAMAN IMPIAN EMAS
# is okay
# CHECKING FOR SK TAMAN MUTIARA RINI 2
# is okay
# CHECKING FOR SK TAMAN MUTIARA RINI
# is okay
# CHECKING FOR SK TAMAN NUSA PERINTIS
# is okay
# CHECKING FOR SK TAMAN PELANGI
# is okay
# CHECKING FOR SK TAMAN PERLING
# is okay
# CHECKING FOR SK TAMAN PERLING 3
# is okay
# CHECKING FOR SK TAMAN SELESA JAYA
# is okay
# CHECKING FOR SK TAMAN SKUDAI BARU 2
# is okay
# CHECKING FOR SK TAMAN SKUDAI BARU
# is okay
# CHECKING FOR SK TAMAN SURIA
# is okay
# CHECKING FOR SK TAMAN SUTERA
# is okay
# CHECKING FOR SK TAMAN TAMPOI UTAMA
# is okay
# CHECKING FOR SK TAMAN TUN AMINAH 2
# is okay
# CHECKING FOR SK TAMAN TUN AMINAH
# is okay
# CHECKING FOR SK TAMAN UNIVERSITI 1
# is not okay
# CHECKING FOR SK TAMAN UNIVERSITI 2
# is okay
# CHECKING FOR SK TAMAN UNIVERSITI 3
# is okay
# CHECKING FOR SK TAMAN UNIVERSITI 4
# is okay
# CHECKING FOR SK TANJONG ADANG
# is okay
# CHECKING FOR SK TANJUNG PUTERI
# is okay
# CHECKING FOR SK TASEK UTARA
# is okay
# CHECKING FOR SK TEBRAU BAKAR BATU
# is okay
# CHECKING FOR SK TEMENGGONG ABDUL RAHMAN 1
# is okay
# CHECKING FOR SK TEMENGGONG ABDUL RAHMAN 2
# is okay
# CHECKING FOR SK TG KUPANG
# is okay
# CHECKING FOR SK TIRAM DUKU
# is okay
# CHECKING FOR SM TEKNIK JOHOR BAHRU
# is okay
# CHECKING FOR SMA AL QURAN WADDIN
# is okay
# CHECKING FOR SMK (P) SULTAN IBRAHIM
# is okay
# CHECKING FOR SMK AMINUDDIN BAKI
# is okay
# CHECKING FOR SMK BANDAR BARU UDA
# is okay
# CHECKING FOR SMK BANDAR UDA UTAMA
# is okay
# CHECKING FOR SMK DAMAI JAYA
# is okay
# CHECKING FOR SMK DATO ABDUL RAHMAN YASSIN
# is okay
# CHECKING FOR SMK DATO JAAFAR
# is okay
# CHECKING FOR SMK DATO_ USMAN AWANG
# is okay
# CHECKING FOR SMK GELANG PATAH
# is okay
# CHECKING FOR SMK IMPIAN EMAS
# is okay
# CHECKING FOR SMK INFANT JESUS CONVENT
# is okay
# CHECKING FOR SMK KOMPLEKS SULTAN ABU BAKAR
# is okay
# CHECKING FOR SMK MAJIDI BARU 2
# is okay
# CHECKING FOR SMK MEDINI
# is okay
# CHECKING FOR SMK MOHD KHALID
# is okay
# CHECKING FOR SMK MUTIARA RINI
# is okay
# CHECKING FOR SMK SAINT JOSEPH
# is okay
# CHECKING FOR SMK SERI PERLING
# is okay
# CHECKING FOR SMK SKUDAI
# is okay
# CHECKING FOR SMK SRI RAHMAT
# is okay
# CHECKING FOR SMK SRI TEBRAU
# is okay
# CHECKING FOR SMK SULTAN ISMAIL
# is okay
# CHECKING FOR SMK SULTANAH ENGKU TUN AMINAH
# is okay
# CHECKING FOR SMK TAMAN BUKIT INDAH
# is okay
# CHECKING FOR SMK TAMAN DAMANSARA ALIFF
# is not okay
# CHECKING FOR SMK TAMAN DESA SKUDAI
# is okay
# CHECKING FOR SMK TAMAN MUTIARA RINI 2
# is okay
# CHECKING FOR SMK TAMAN NUSAJAYA
# is okay
# CHECKING FOR SMK TAMAN PELANGI
# is okay
# CHECKING FOR SMK TAMAN SELESA JAYA 2
# is okay
# CHECKING FOR SMK TAMAN SELESA JAYA
# is okay
# CHECKING FOR SMK TAMAN SUTERA
# is okay
# CHECKING FOR SMK TAMAN TUN AMINAH
# is okay
# CHECKING FOR SMK TAMAN UNIVERSITI 2
# is okay
# CHECKING FOR SMK TAMAN UNIVERSITI
# is okay
# CHECKING FOR SMK TAN SRI MOHAMED RAHMAT
# is okay
# CHECKING FOR SMK TANJUNG ADANG
# is okay
# CHECKING FOR SMK TASEK UTARA 2
# is okay
# CHECKING FOR SMK TASEK UTARA
# is okay
# CHECKING FOR SMK TUN SYED NASIR ISMAIL
# is okay
# CHECKING FOR SR AGAMA BERSEPADU JOHOR BAHRU
# is okay

# %% [markdown]
# ## Test name searching algorithm for teacher name

# %%
import textdistance

dropdownName = ["AHMAD SHAHRILLAFIZAN BIN HUSSAIN",
                "ABDUL HARIZ BIN ABDULL SAMAT",
                "AMIRO BIN KAMIRON",
                "ANIZAH BINTI MOHD DAUD",
                "AZIMY BIN MOHD BUKHARI",
                "AZIZUL ARIF BIN ZULKAFLEE",
                "BAHARUDDIN B ABDULLAH",
                "DZULKIFLI B BAKAR",
                "FAAIZUN BINTI  BASO SULTAN BAKRI",
                "FAEZA BINTI OMAR",
                "FARHAH BINTI JAFFAR",
                "FARISSHA BINTI ALLUWI",
                "HALIZA ABD HAMID",
                "HARTINI BINTI BUANG",
                "HASFARINA BINTI ABAS",
                "HERLINA BINTI MOHD HARON",
                "HUDA BINTI HUSSEIN",
                "JESLINDA A/P SELVARAJU",
                "JOHARI BIN JAMIL",
                "JUHAIDA HUSNA BINTI MD. SHUKOR",
                "JUWIESA ANAK BAYANG",
                "KARTINI BINTI HANAPI",
                "KHAIRIL AZHAR BIN ROSNI",
                "KHAIRUNNISA BINTI KAMARULZAMAN",
                "KHAIRUNNISYA BINTI UBAIDULLAH",
                "LIEW CHOI LING",
                "LILY SUHANY BT MAHMOOD",
                "LIM KA BOOI"
]

testName = [None,
            'LIM KA BOOI',
           'faaizun'
           ]



for i in range(len(testName)):
    if testName[i] == None:
        result = testName[0]
        print(str(i) + ". Tested name does not exist, so the result defaul to : " + str(result))
    else:
        best_match_similarity = 0
        best_match_option = None
        # Loop through the options and find the best match for the partial name
        for option in dropdownName:
            similarity = textdistance.jaro_winkler.normalized_similarity(testName[i].lower(), option.lower())
            if similarity > best_match_similarity:
                best_match_similarity = similarity
                best_match_option = option

        # Check if a best match was found and select it
        if best_match_option is not None:
            result = best_match_option
            print(str(i) + ". Tested name: ")
            print(testName[i])
            print("Predicted name:")
            print(result)
            print( "Similarity percentage: " + str(round((similarity*100),1)) + "%")
            print('')
        else:
            # Handle the case when no match was found
            result = 'none'
            
            print(result)

# %% [markdown]
# ## Convert list of school from csv to seperate json

# %%
import csv
import json

# Define the input and output file paths
csv_file = '/Users/piixel/Downloads/SSDM LOGIN TERENGGANU.xlsx - Sheet1.csv'
json_file = '/Users/piixel/Desktop/data.json'

# Initialize an empty list to store the data
data = []

# Read the CSV file and convert it to a list of dictionaries
with open(csv_file, 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        data.append(row)

# Write the data to a JSON file
with open(json_file, 'w') as json_file:
    json.dump(data, json_file, indent=4)

print(f'CSV file "{csv_file}" has been converted to JSON file "{json_file}".')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/_1/c3p6n34x7s73jyj1_5n9nt7r0000gn/T/ipykernel_10003/1761979645.py in <module>
#       5 import csv
#       6 from wrapper_script import AppDirectory
# ----> 7 from wrapper_script import MainVariable
#       8
#       9 # Set paths and filenames
#
# ImportError: cannot import name 'MainVariable' from 'wrapper_script' (/Users/piixel/Desktop/ssdmV2/wrapper_script.py)

# %% [markdown]
# ## Mass set inactive status for single school

# %%
import json
import pymongo
from bson import ObjectId
from datetime import datetime
from pathlib import Path

#datetime(year, month, day)
start_date = datetime(2023, 1, 1)   #adjust accordingly
end_date = datetime(2023, 1, 1)

current_dir = Path.cwd()
config_dir = current_dir / "config.json"

# Read data from the JSON file
with open(config_dir, 'r') as jsonfile:
    config = json.load(jsonfile)

#make sure to initiate vpn to production db first
db = config['DATABASE']
DBclient = pymongo.MongoClient(db['connection'])
DBcol = DBclient[db['collection']]
DBdoc = DBcol[db['document']]

#load school detail from config
school = config['TERENGGANU_DETAIL']

#set the corresponding schoolID
filter_criteria = {"schoolID": ObjectId('64c54de0b4d7f977154f2564'),
                   "created_at": {"$gte": start_date, "$lte": end_date}
                   }
#set all filtered item to inactive (1:active, 2:inactive)
results = DBdoc.update_many(filter_criteria, {"$set": {"status": 2}})

# %% [markdown]
# ## Check number of submissions for a time period

# %%
import json
import pymongo
from bson import ObjectId
from datetime import datetime
from pathlib import Path

#datetime(year, month, day)
start_date = datetime(2023, 10, 1)   #adjust accordingly
end_date = datetime(2023, 10, 31)

current_dir = Path.cwd()
config_dir = current_dir / "config.json"

# Read data from the JSON file
with open(config_dir, 'r') as jsonfile:
    config = json.load(jsonfile)

#make sure to initiate vpn to production db first
db = config['DATABASE']
DBclient = pymongo.MongoClient(db['connection'])
DBcol = DBclient[db['collection']]
DBdoc = DBcol[db['document']]

#load school detail from config
school = config['JOHOR']

#set the corresponding schoolID
filter_criteria = {"schoolID": ObjectId('62bc5d3d9ab3130ba059a0e9'), #change shccol ID appropriately
                   "created_at": {"$gte": start_date, "$lte": end_date}
                   }
submissions = DBdoc.count_documents(filter_criteria)
print(f"Number of submissions: {submissions}")
# Out:
# Number of submissions: 22553

# %% [markdown]
# ## Download Data for Single School

# %%
import json
import pymongo
import pandas as pd
import os
import shutil
from bson import ObjectId
from datetime import datetime
from pathlib import Path

current_dir = Path.cwd()
config_dir = current_dir / "config.json"
#this will configure your download folder
download_dir = current_dir / "data"

# Save the DataFrame to a CSV file
if os.path.exists(str(download_dir)):
    shutil.rmtree(str(download_dir))  # Remove the existing directory and its contents
os.makedirs(str(download_dir))

# Read data from the JSON file
with open(config_dir, 'r') as jsonfile:
    config = json.load(jsonfile)

synced = 0
    
#make sure to initiate vpn to production db first
db = config['DATABASE']
DBclient = pymongo.MongoClient(db['connection'])
DBcol = DBclient[db['collection']]
DBdoc = DBcol[db['document']]

# datetime(year, month, day)
start_date = datetime(2023, 5, 1)
end_date = datetime(2023, 5, 31)

#insert school mongodb id here
filter_criteria = {"schoolID": ObjectId('6136dbd16d43d74b3fb43625'),
                   "created_at": {"$gte": start_date, "$lte": end_date}}

# Define the projection to exclude specific fields (e.g., "field_to_exclude")
exclude = {"_id": 0, "tempat":0, "ic":0, "userID":0, "schoolID":0, "method":0, "updated_at":0, "created_at":0, "submissionID":0}
results = DBdoc.find(filter_criteria, exclude)

#turn query result into dataframe
df = pd.DataFrame(list(results))
df['synced'] = synced

#do not print to csv if empty + insert school name manually
if df.empty:
    print("SK SERI PERLING 2" + " has no submissions")
else:
    #output to csv
    df.to_csv(str(download_dir) + "/" + row['NAME'] + ".csv", index=False)
    print("SK SERI PERLING 2" + " data has been generated")

    #set all filtered item to inactive (1:active, 2:inactive)
    results = DBdoc.update_many(filter_criteria, {"$set": {"status": 2}})
    
DBclient.close()
# Out:
# SK SERI PERLING 2 has no submissions
