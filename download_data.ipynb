# %%
import json
import pymongo
import pandas as pd
import os
import shutil
from bson import ObjectId
from datetime import datetime
from pathlib import Path

# Define a function to update column 'syncedBySchool' based on the values in column 'status'
def update_column(row):
    if row['status'] == 2:
        return 1  # Set 'syncedBySchool' to 1 when 'status' is 2
    else:
        return 0  # Set 'syncedBySchool' to 0 when 'status' is 1

#datetime(year, month, day)
start_date = datetime(2023, 10, 1)
end_date = datetime(2023, 10, 31)

current_directory = Path.cwd()
configPath = current_directory / "config.json"

#this will configure your download folder
downloadDirectory = current_directory / "data_ssdm"


# Save the DataFrame to a CSV file
if os.path.exists(str(downloadDirectory)):
    shutil.rmtree(str(downloadDirectory))  # Remove the existing directory and its contents
os.makedirs(str(downloadDirectory))

# Read data from the JSON file
with open(configPath, 'r') as jsonfile:
    config = json.load(jsonfile)

#make sure to initiate vpn to production db first
db = config['DATABASE']
DBclient = pymongo.MongoClient(db['connection'])
DBcol = DBclient[db['collection']]
DBdoc = DBcol[db['document']]

#load school detail from config
school = config['JB_DETAIL']
synced = 0
syncedBySchool = 0

for row in school:
    # Define the filter criteria using the ObjectId instance
    filter_criteria = {"schoolID": ObjectId(row['mongoDB_ID']),
                    "created_at": {"$gte": start_date, "$lte": end_date}
                    }

    # Define the projection to exclude specific fields (e.g., "field_to_exclude")
    exclude = {"_id": 0, "tempat":0, "ic":0, "userID":0, "schoolID":0, "method":0, "updated_at":0, "created_at":0, "submissionID":0}
    results = DBdoc.find(filter_criteria, exclude)
    
    #turn query result into dataframe
    df = pd.DataFrame(list(results))
    df['syncedBySchool'] = syncedBySchool
    df['syncedBySchool'] = df.apply(update_column, axis=1)
    df['synced'] = synced
    
    #set all filtered item to inactive (1:active, 2:inactive)
    results = DBdoc.update_many(filter_criteria, {"$set": {"status": 2}})
    
    #do not print to csv if empty
    if df.empty:
        print(row['NAME'] + " has no submissions")
        continue
    
    #output to csv
    df.to_csv(str(downloadDirectory) + "/" + row['NAME'] + ".csv", index=False)
    print(row['NAME'] + " data has been generated")
# Out:
# KV (ERT) AZIZAH data has been generated
# KV PERDAGANGAN has no submissions
# KV TANJUNG PUTERI has no submissions
# MAKTAB SULTAN ABU BAKAR data has been generated
# SEKOLAH TUN FATIMAH data has been generated
# SJK (CINA) CHEAH FAH has no submissions
# SJK (CINA) FOON YEW 1 data has been generated
# SJK (CINA) FOON YEW 2 has no submissions
# SJK (CINA) FOON YEW 3 has no submissions
# SJK (CINA) FOON YEW 4 data has been generated
# SJK (CINA) KEMPAS BARU data has been generated
# SJK (CINA) KUO KUANG data has been generated
# SJK (CINA) KUO KUANG 2 data has been generated
# SJK (CINA) MING CHIH data has been generated
# SJK (CINA) MING TERK has no submissions
# SJK (CINA) PAI TZE data has been generated
# SJK (CINA) PEI HWA data has been generated
# SJK (CINA) PING MING data has been generated
# SJK (CINA) PU SZE has no submissions
# SJK (CINA) ST JOSEPH data has been generated
# SJK (CINA) TAMPOI data has been generated
# SJK (CINA) THAI HONG data has been generated
# SJK (CINA) THORBURN data has been generated
# SJK (TAMIL) GELANG PATAH data has been generated
# SJK (TAMIL) JALAN YAHYA AWAL data has been generated
# SJK (TAMIL) LADANG BUKIT SERAMPANG data has been generated
# SJK (TAMIL) LADANG RINI has no submissions
# SJK (TAMIL) TAMAN TUN AMINAH data has been generated
# SK (P) BANDAR TINGGI data has been generated
# SK (P) JLN. YAHYA AWAL data has been generated
# SK (P) SULTAN IBRAHIM data has been generated
# SK ANGKATAN TENTERA data has been generated
# SK AYER MOLEK data has been generated
# SK BANDAR UDA 2 data has been generated
# SK BUKIT MUTIARA data has been generated
# SK GELANG PATAH data has been generated
# SK INFANT JESUS CONVENT data has been generated
# SK KAMPUNG PULAI data has been generated
# SK KEMPAS data has been generated
# SK KG PASIR data has been generated
# SK KG. MAJU JAYA data has been generated
# SK KOMPLEKS SULTAN ABU BAKAR data has been generated
# SK KOMPLEKS UDA data has been generated
# SK LADANG PENDAS has no submissions
# SK LARKIN 1 data has been generated
# SK LARKIN 2 data has been generated
# SK MAJIDI BARU data has been generated
# SK MEDINI data has been generated
# SK MOHD KHIR JOHARI data has been generated
# SK MORNI POK data has been generated
# SK NGEE HENG data has been generated
# SK NONG CHIK data has been generated
# SK NUSANTARA data has been generated
# SK PENDAS LAUT data has been generated
# SK PENDIDIKAN KHAS JOHOR BAHRU data has been generated
# SK PENDIDIKAN KHAS PRINCESS ELIZABETH has no submissions
# SK PENGKALAN RINTING data has been generated
# SK PERUMAHAN TAMPOI 2 data has been generated
# SK SEKUDAI BT 10 data has been generated
# SK SERI KENANGA data has been generated
# SK SERI MELATI data has been generated
# SK SERI PERLING 2 data has been generated
# SK SIKIJANG data has been generated
# SK SRI AMAR data has been generated
# SK SRI SKUDAI data has been generated
# SK SRI TEBRAU data has been generated
# SK ST. JOSEPH data has been generated
# SK SUNGAI DANGA data has been generated
# SK SUNGAI MELAYU data has been generated
# SK TAMAN ANGGERIK data has been generated
# SK TAMAN BUKIT INDAH data has been generated
# SK TAMAN BUKIT KEMPAS data has been generated
# SK TAMAN BUKIT MEWAH data has been generated
# SK TAMAN CEMPAKA data has been generated
# SK TAMAN DAMAI JAYA data has been generated
# SK TAMAN DAMANSARA ALIFF has no submissions
# SK TAMAN DESA SKUDAI data has been generated
# SK TAMAN IMPIAN EMAS data has been generated
# SK TAMAN MUTIARA RINI data has been generated
# SK TAMAN MUTIARA RINI 2 has no submissions
# SK TAMAN NUSA PERINTIS data has been generated
# SK TAMAN PELANGI data has been generated
# SK TAMAN PERLING data has been generated
# SK TAMAN PERLING 3 data has been generated
# SK TAMAN SELESA JAYA data has been generated
# SK TAMAN SKUDAI BARU data has been generated
# SK TAMAN SKUDAI BARU 2 data has been generated
# SK TAMAN SURIA data has been generated
# SK TAMAN SUTERA data has been generated
# SK TAMAN TAMPOI UTAMA data has been generated
# SK TAMAN TUN AMINAH data has been generated
# SK TAMAN TUN AMINAH 2 data has been generated
# SK TAMAN UNIVERSITI 1 has no submissions
# SK TAMAN UNIVERSITI 2 data has been generated
# SK TAMAN UNIVERSITI 3 data has been generated
# SK TAMAN UNIVERSITI 4 data has been generated
# SK TANJONG ADANG data has been generated
# SK TANJUNG PUTERI data has been generated
# SK TASEK UTARA data has been generated
# SK TEBRAU BAKAR BATU data has been generated
# SK TEMENGGONG ABDUL RAHMAN 1 data has been generated
# SK TEMENGGONG ABDUL RAHMAN 2 data has been generated
# SK TG KUPANG data has been generated
# SK TIRAM DUKU data has been generated
# SM TEKNIK JOHOR BAHRU data has been generated
# SMA AL QURAN WADDIN data has been generated
# SMK (P) SULTAN IBRAHIM data has been generated
# SMK AMINUDDIN BAKI data has been generated
# SMK BANDAR BARU UDA data has been generated
# SMK BANDAR UDA UTAMA data has been generated
# SMK DAMAI JAYA data has been generated
# SMK DATO ABDUL RAHMAN YASSIN data has been generated
# SMK DATO JAAFAR data has been generated
# SMK DATO' USMAN AWANG data has been generated
# SMK GELANG PATAH data has been generated
# SMK IMPIAN EMAS data has been generated
# SMK INFANT JESUS CONVENT data has been generated
# SMK KOMPLEKS SULTAN ABU BAKAR data has been generated
# SMK MAJIDI BARU 2 data has been generated
# SMK MEDINI data has been generated
# SMK MOHD KHALID has no submissions
# SMK MUTIARA RINI data has been generated
# SMK SAINT JOSEPH has no submissions
# SMK SERI PERLING data has been generated
# SMK SKUDAI has no submissions
# SMK SRI RAHMAT data has been generated
# SMK SRI TEBRAU data has been generated
# SMK SULTAN ISMAIL data has been generated
# SMK SULTANAH ENGKU TUN AMINAH data has been generated
# SMK TAMAN BUKIT INDAH data has been generated
# SMK TAMAN DAMANSARA ALIFF has no submissions
# SMK TAMAN DESA SKUDAI data has been generated
# SMK TAMAN MUTIARA RINI 2 data has been generated
# SMK TAMAN NUSAJAYA data has been generated
# SMK TAMAN PELANGI data has been generated
# SMK TAMAN SELESA JAYA data has been generated
# SMK TAMAN SELESA JAYA 2 data has been generated
# SMK TAMAN SUTERA data has been generated
# SMK TAMAN TUN AMINAH data has been generated
# SMK TAMAN UNIVERSITI data has been generated
# SMK TAMAN UNIVERSITI 2 data has been generated
# SMK TAN SRI MOHAMED RAHMAT data has been generated
# SMK TANJUNG ADANG data has been generated
# SMK TASEK UTARA data has been generated
# SMK TASEK UTARA 2 data has been generated
# SMK TUN SYED NASIR ISMAIL has no submissions
# SR AGAMA BERSEPADU JOHOR BAHRU has no submissions
