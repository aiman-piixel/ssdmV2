# %%
import os
import json
import glob
import pandas as pd
from pathlib import Path
import csv

# Set paths and filenames
current_directory = Path.cwd()
configPath = current_directory / "config.json"
csv_path = current_directory / "data_ssdm"
login_path = current_directory / "login_detail.csv"

# Read data from the JSON file
with open(configPath, 'r') as jsonfile:
    config = json.load(jsonfile)
school = config.get('JB_DETAIL', [])  # Use get() to handle missing key gracefully

# Find all CSV files in data_ssdm directory
csvFiles = glob.glob(os.path.join(str(csv_path), "*.csv"))
csvFiles.sort()

csvNames = []
for file in csvFiles:
    clean = file.replace(str(csv_path)+'/','').replace('.csv','')
    csvNames.append(clean)

# Define the list of headers
headers = ['NAME', 'ssdmID', 'ssdmPass', 'done']  # Replace with your actual headers

# Create and write to the CSV file
with open(str(login_path), 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write the headers to the CSV file
    csv_writer.writerow(headers)

name_to_index = {name: index for index, name in enumerate(csvNames)}

df = pd.read_csv(str(login_path))

index = 0
for row in school:
    name = row.get('NAME')
    if name in name_to_index:
        count = name_to_index[name]
        setName = row.get('NAME')
        setID = row.get('ID')
        setPass = row.get('PASS')
        df.at[count, 'NAME'] = setName
        df.at[count, 'ssdmID'] = setID
        df.at[count, 'ssdmPass'] = setPass
        print(row['NAME'] + ' detail has been included in login_detail.xlsx ')
        index += 1

# Reset completion value
df['done'] = 0

df.to_csv(str(login_path), index=False)
# Out:
# KV (ERT) AZIZAH detail has been included in login_detail.xlsx
# MAKTAB SULTAN ABU BAKAR detail has been included in login_detail.xlsx
# SEKOLAH TUN FATIMAH detail has been included in login_detail.xlsx
# SJK (CINA) FOON YEW 1 detail has been included in login_detail.xlsx
# SJK (CINA) FOON YEW 4 detail has been included in login_detail.xlsx
# SJK (CINA) KEMPAS BARU detail has been included in login_detail.xlsx
# SJK (CINA) KUO KUANG 2 detail has been included in login_detail.xlsx
# SJK (CINA) KUO KUANG detail has been included in login_detail.xlsx
# SJK (CINA) MING CHIH detail has been included in login_detail.xlsx
# SJK (CINA) PAI TZE detail has been included in login_detail.xlsx
# SJK (CINA) PEI HWA detail has been included in login_detail.xlsx
# SJK (CINA) PING MING detail has been included in login_detail.xlsx
# SJK (CINA) ST JOSEPH detail has been included in login_detail.xlsx
# SJK (CINA) TAMPOI detail has been included in login_detail.xlsx
# SJK (CINA) THAI HONG detail has been included in login_detail.xlsx
# SJK (CINA) THORBURN detail has been included in login_detail.xlsx
# SJK (TAMIL) GELANG PATAH detail has been included in login_detail.xlsx
# SJK (TAMIL) JALAN YAHYA AWAL detail has been included in login_detail.xlsx
# SJK (TAMIL) LADANG BUKIT SERAMPANG detail has been included in login_detail.xlsx
# SJK (TAMIL) TAMAN TUN AMINAH detail has been included in login_detail.xlsx
# SK (P) BANDAR TINGGI detail has been included in login_detail.xlsx
# SK (P) JLN. YAHYA AWAL detail has been included in login_detail.xlsx
# SK (P) SULTAN IBRAHIM detail has been included in login_detail.xlsx
# SK ANGKATAN TENTERA detail has been included in login_detail.xlsx
# SK AYER MOLEK detail has been included in login_detail.xlsx
# SK BANDAR UDA 2 detail has been included in login_detail.xlsx
# SK BUKIT MUTIARA detail has been included in login_detail.xlsx
# SK GELANG PATAH detail has been included in login_detail.xlsx
# SK INFANT JESUS CONVENT detail has been included in login_detail.xlsx
# SK KAMPUNG PULAI detail has been included in login_detail.xlsx
# SK KEMPAS detail has been included in login_detail.xlsx
# SK KG PASIR detail has been included in login_detail.xlsx
# SK KG. MAJU JAYA detail has been included in login_detail.xlsx
# SK KOMPLEKS SULTAN ABU BAKAR detail has been included in login_detail.xlsx
# SK KOMPLEKS UDA detail has been included in login_detail.xlsx
# SK LARKIN 1 detail has been included in login_detail.xlsx
# SK LARKIN 2 detail has been included in login_detail.xlsx
# SK MAJIDI BARU detail has been included in login_detail.xlsx
# SK MEDINI detail has been included in login_detail.xlsx
# SK MOHD KHIR JOHARI detail has been included in login_detail.xlsx
# SK MORNI POK detail has been included in login_detail.xlsx
# SK NGEE HENG detail has been included in login_detail.xlsx
# SK NONG CHIK detail has been included in login_detail.xlsx
# SK NUSANTARA detail has been included in login_detail.xlsx
# SK PENDAS LAUT detail has been included in login_detail.xlsx
# SK PENDIDIKAN KHAS JOHOR BAHRU detail has been included in login_detail.xlsx
# SK PENGKALAN RINTING detail has been included in login_detail.xlsx
# SK PERUMAHAN TAMPOI 2 detail has been included in login_detail.xlsx
# SK SEKUDAI BT 10 detail has been included in login_detail.xlsx
# SK SERI KENANGA detail has been included in login_detail.xlsx
# SK SERI MELATI detail has been included in login_detail.xlsx
# SK SERI PERLING 2 detail has been included in login_detail.xlsx
# SK SIKIJANG detail has been included in login_detail.xlsx
# SK SRI AMAR detail has been included in login_detail.xlsx
# SK SRI SKUDAI detail has been included in login_detail.xlsx
# SK SRI TEBRAU detail has been included in login_detail.xlsx
# SK ST. JOSEPH detail has been included in login_detail.xlsx
# SK SUNGAI DANGA detail has been included in login_detail.xlsx
# SK SUNGAI MELAYU detail has been included in login_detail.xlsx
# SK TAMAN ANGGERIK detail has been included in login_detail.xlsx
# SK TAMAN BUKIT INDAH detail has been included in login_detail.xlsx
# SK TAMAN BUKIT KEMPAS detail has been included in login_detail.xlsx
# SK TAMAN BUKIT MEWAH detail has been included in login_detail.xlsx
# SK TAMAN CEMPAKA detail has been included in login_detail.xlsx
# SK TAMAN DAMAI JAYA detail has been included in login_detail.xlsx
# SK TAMAN DESA SKUDAI detail has been included in login_detail.xlsx
# SK TAMAN IMPIAN EMAS detail has been included in login_detail.xlsx
# SK TAMAN MUTIARA RINI detail has been included in login_detail.xlsx
# SK TAMAN NUSA PERINTIS detail has been included in login_detail.xlsx
# SK TAMAN PELANGI detail has been included in login_detail.xlsx
# SK TAMAN PERLING detail has been included in login_detail.xlsx
# SK TAMAN PERLING 3 detail has been included in login_detail.xlsx
# SK TAMAN SELESA JAYA detail has been included in login_detail.xlsx
# SK TAMAN SKUDAI BARU 2 detail has been included in login_detail.xlsx
# SK TAMAN SKUDAI BARU detail has been included in login_detail.xlsx
# SK TAMAN SURIA detail has been included in login_detail.xlsx
# SK TAMAN SUTERA detail has been included in login_detail.xlsx
# SK TAMAN TAMPOI UTAMA detail has been included in login_detail.xlsx
# SK TAMAN TUN AMINAH 2 detail has been included in login_detail.xlsx
# SK TAMAN TUN AMINAH detail has been included in login_detail.xlsx
# SK TAMAN UNIVERSITI 2 detail has been included in login_detail.xlsx
# SK TAMAN UNIVERSITI 3 detail has been included in login_detail.xlsx
# SK TAMAN UNIVERSITI 4 detail has been included in login_detail.xlsx
# SK TANJONG ADANG detail has been included in login_detail.xlsx
# SK TANJUNG PUTERI detail has been included in login_detail.xlsx
# SK TASEK UTARA detail has been included in login_detail.xlsx
# SK TEBRAU BAKAR BATU detail has been included in login_detail.xlsx
# SK TEMENGGONG ABDUL RAHMAN 1 detail has been included in login_detail.xlsx
# SK TEMENGGONG ABDUL RAHMAN 2 detail has been included in login_detail.xlsx
# SK TG KUPANG detail has been included in login_detail.xlsx
# SK TIRAM DUKU detail has been included in login_detail.xlsx
# SM TEKNIK JOHOR BAHRU detail has been included in login_detail.xlsx
# SMA AL QURAN WADDIN detail has been included in login_detail.xlsx
# SMK (P) SULTAN IBRAHIM detail has been included in login_detail.xlsx
# SMK AMINUDDIN BAKI detail has been included in login_detail.xlsx
# SMK BANDAR BARU UDA detail has been included in login_detail.xlsx
# SMK BANDAR UDA UTAMA detail has been included in login_detail.xlsx
# SMK DAMAI JAYA detail has been included in login_detail.xlsx
# SMK DATO ABDUL RAHMAN YASSIN detail has been included in login_detail.xlsx
# SMK DATO JAAFAR detail has been included in login_detail.xlsx
# SMK DATO' USMAN AWANG detail has been included in login_detail.xlsx
# SMK GELANG PATAH detail has been included in login_detail.xlsx
# SMK IMPIAN EMAS detail has been included in login_detail.xlsx
# SMK INFANT JESUS CONVENT detail has been included in login_detail.xlsx
# SMK KOMPLEKS SULTAN ABU BAKAR detail has been included in login_detail.xlsx
# SMK MAJIDI BARU 2 detail has been included in login_detail.xlsx
# SMK MEDINI detail has been included in login_detail.xlsx
# SMK MUTIARA RINI detail has been included in login_detail.xlsx
# SMK SERI PERLING detail has been included in login_detail.xlsx
# SMK SRI RAHMAT detail has been included in login_detail.xlsx
# SMK SRI TEBRAU detail has been included in login_detail.xlsx
# SMK SULTAN ISMAIL detail has been included in login_detail.xlsx
# SMK SULTANAH ENGKU TUN AMINAH detail has been included in login_detail.xlsx
# SMK TAMAN BUKIT INDAH detail has been included in login_detail.xlsx
# SMK TAMAN DESA SKUDAI detail has been included in login_detail.xlsx
# SMK TAMAN MUTIARA RINI 2 detail has been included in login_detail.xlsx
# SMK TAMAN NUSAJAYA detail has been included in login_detail.xlsx
# SMK TAMAN PELANGI detail has been included in login_detail.xlsx
# SMK TAMAN SELESA JAYA 2 detail has been included in login_detail.xlsx
# SMK TAMAN SELESA JAYA detail has been included in login_detail.xlsx
# SMK TAMAN SUTERA detail has been included in login_detail.xlsx
# SMK TAMAN TUN AMINAH detail has been included in login_detail.xlsx
# SMK TAMAN UNIVERSITI 2 detail has been included in login_detail.xlsx
# SMK TAMAN UNIVERSITI detail has been included in login_detail.xlsx
# SMK TAN SRI MOHAMED RAHMAT detail has been included in login_detail.xlsx
# SMK TANJUNG ADANG detail has been included in login_detail.xlsx
# SMK TASEK UTARA 2 detail has been included in login_detail.xlsx
# SMK TASEK UTARA detail has been included in login_detail.xlsx
